# %%
d = {"a": 10, "b": 20} 

print("Dictionary:", 
d["c"] = 30
print("After adding:", d) 


del d["b"]
print("After removing:", d)



t = (10, 20, 30)
print("Tuple:", t)


t = t + (40,)
print("After adding:", t)


t = (10, 20, 40)
print("After removing:", t)
